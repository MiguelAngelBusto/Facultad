# %% [markdown]
# ![image.png](attachment:c28b0af5-5ca0-4da8-a4fa-69f5bf333bfa.png)

# %%
from matplotlib import pyplot
import math as ma
import numpy as np
def f1(a):
    return (a**-1)- ma.tan(a)

x = np.linspace(0.5,np.pi/2, 10)
y= f1(x)
fig = plt.figure(figsize= (10,5))
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5     return (a**-1)- ma.tan(a)
#       7 x = np.linspace(0.5,np.pi, 10)
# ----> 8 y= f1(x)
#       9 fig = plt.figure(figsize= (10,5))
#      10 plt.plot(x,y)
#
# Cell In[4], line 5, in f1(a)
#       4 def f1(a):
# ----> 5     return (a**-1)- ma.tan(a)
#
# TypeError: only length-1 arrays can be converted to Python scalars
