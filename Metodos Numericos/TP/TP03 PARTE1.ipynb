# %% [markdown]
# ![image.png](attachment:6c5496d6-fe5c-4c94-bc0f-2e8a8a1701cd.png)

# %% [markdown]
# **Ejercicio a)**
#
# A = ![image.png](attachment:05d42491-945a-4fd7-94ff-ec47009620a7.png)  b= ![image.png](attachment:c0b98efe-becd-45c9-9929-e6116be523a2.png)  x= ![image.png](attachment:58db9580-a763-4fc8-b0ae-df24e84df1e4.png)
#
# **Calculos:**
#
# x3 = b[3] / A[3][3]
#
# x3 = 6 / 3
#
# x3 = 2
#
# x2= ( b[2] - A[2][3] * x3 ) / A[2][2]
#
# x2 = ( 24 - 4*2 ) / -2
#
# x2 = -8
#
# x1= ( b[0] - A[1][2] * x2 - A[1][3] * x3 ) / A[1][1]
#
# x2 = (-5 - ( 2*(-8) )- ( 3*2 )) / 5
#
# x2 = 1
#
# x = ![image.png](attachment:9fad3a38-236c-4a60-aadd-f71693a5379e.png)

# %% [markdown]
# ##### Ejercicio b)
# A = ![image.png](attachment:0f9907a7-0b9f-4c0f-943a-f45dde640654.png) b = ![image.png](attachment:b71f38da-943f-4fae-9fb9-fa4bb72af52c.png)  x = ![image.png](attachment:c323cdee-2613-42dc-986d-99a519949bf4.png)
#
# CALCULOS:
#
# x1= b[1] / A[1][1]
#
# x1= 6 / 2
#
# x1= 3
#
# x2= ( b[2] - A[2][1] * x1 ) / A[2][2]
#
# x2= ( 4 - ( 1 * 3) ) / 1
#
# x2= 1
#
# x3= ( b[3] - A[3][1] * x1 - A[3][2] * x2 ) / A[3][3]
#
# x3= ( 15 - ( 3 * 3 ) - ( -2 * 1 ) ) / 4
#
# x3= 2
#
# x =
# print("\nx =\n",

# %% [markdown]
# ![image.png](attachment:4c4a1d8c-8089-4659-b33b-7a5f2913d011.png)

# %% [markdown]
# **Ejercicio a)**
#
# A = ![image.png](attachment:3261eec1-29c2-4ffa-b037-b8e01bd354e3.png) b = ![image.png](attachment:7bb19e92-0f60-4b1f-a222-dffe3f15f1ea.png)  x = ![image.png](attachment:bbf8b27e-a11e-40e0-9756-1f0f613cacb6.png)
#
# print("A1 = ",matriz[0][0])
# m31 = matriz[2][0]/matriz[0][0]
# print("m31 = ",m31)
# matriz[2][0] = matriz[2][0] - m31*matriz[0][0]
# matriz[2][1] = matriz[2][1] - m31*matriz[0][1]
# matriz[2][2] = matriz[2][2] - m31*matriz[0][2]
#
# print("A= \n",matriz)
