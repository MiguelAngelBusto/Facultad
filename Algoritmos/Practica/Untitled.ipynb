# %% [markdown]
# ![image.png](attachment:bfc9dfdf-6c62-4984-9dcf-c568a36bc526.png)

# %% [markdown]
# ![image.png](attachment:5989d6e6-f7aa-4077-860f-8235e46f70f5.png)

# %% [markdown]
# a) ![image.png](attachment:715f676c-9a1c-4314-b69d-bbe1efb73494.png)
#
# ![image.png](attachment:8bf62de1-0d2f-40a4-b152-041942d58f05.png)

# %% [markdown]
# b) ![image.png](attachment:f8ef9020-dc31-4a05-9e35-cab628790d30.png)

# %% [markdown]
# c)
#
# ![image.png](attachment:c9935502-69f3-4d42-acfc-253aa7cadcce.png)
#
#     Fila  | Listados            Bfs(1) = <1,2,3,5,4>
#      FV   |    -                Bfs(2) = <>
#       1   |    1                Bfs(3) = <>
#     2,3,5 |    2                Bfs(4) = <>
#      3,5  |    3                Bfs(5) = <>
#      5,4  |    5
#       4   |    4
#      FV   |    -

# %% [markdown]
# d)
#
# ![image.png](attachment:91fedbc4-4091-40aa-94c9-03b15d793b94.png)
#
#     Dfs(1) = <1,2,3,4,5>
#     Dfs(2) = <>
#     Dfs(3) = <>
#     Dfs(4) = <>
#     Dfs(5) = <>

# %% [markdown]
# e)
#
# ![image.png](attachment:a4dd6fe1-176e-420b-a957-5be8ca33d3e0.png)
#
#     Nodo  | Previo
#       -   |    -                OT: ( 4 5 3 2 1 )
#       1   |  2,3,5
#       2   |   1,3
#       3   |  1,2,5
#       4   |    5
#       5   |  1,3,4
#       -   |    -
